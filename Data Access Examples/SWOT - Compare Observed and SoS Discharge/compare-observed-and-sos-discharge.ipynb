# %% [markdown]
# # Compare Observed and SoS-computed Discharge

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Collecting hsclient==1.1.6 (from -r requirements.txt (line 2))
#   Using cached hsclient-1.1.6-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: pandas==2.2.3 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: earthaccess in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: xarray in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2025.1.2)
# Requirement already satisfied: h5netcdf in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: zarr in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (3.0.5)
# Requirement already satisfied: hsmodels>=1.0.4 in /opt/conda/lib/python3.11/site-packages (from hsclient==1.1.6->-r requirements.txt (line 2)) (1.0.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from hsclient==1.1.6->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: requests_oauthlib in /opt/conda/lib/python3.11/site-packages (from hsclient==1.1.6->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from hsclient==1.1.6->-r requirements.txt (line 2)) (75.1.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (6.5.4)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.5)
# Requirement already satisfied: jupyterlab in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (3.6.8)
# Requirement already satisfied: fsspec>=2022.11 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: importlib-resources>=6.3.2 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (6.4.5)
# Requirement already satisfied: multimethod>=1.8 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (2.0)
# Requirement already satisfied: pqdm>=0.1 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: python-cmr>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (0.13.0)
# Requirement already satisfied: s3fs>=2022.11 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: tinynetrc>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from earthaccess->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in /opt/conda/lib/python3.11/site-packages (from xarray->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (from h5netcdf->-r requirements.txt (line 6)) (3.13.0)
# Requirement already satisfied: donfig>=0.8 in /opt/conda/lib/python3.11/site-packages (from zarr->-r requirements.txt (line 7)) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /opt/conda/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->-r requirements.txt (line 7)) (0.15.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from donfig>=0.8->zarr->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: rdflib<6.0.0 in /opt/conda/lib/python3.11/site-packages (from hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: pydantic==2.7.* in /opt/conda/lib/python3.11/site-packages (from hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (2.7.4)
# Requirement already satisfied: email-validator in /opt/conda/lib/python3.11/site-packages (from hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic==2.7.*->hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/conda/lib/python3.11/site-packages (from pydantic==2.7.*->hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (2.18.4)
# Requirement already satisfied: deprecated in /opt/conda/lib/python3.11/site-packages (from numcodecs>=0.14->numcodecs[crc32c]>=0.14->zarr->-r requirements.txt (line 7)) (1.2.18)
# Requirement already satisfied: crc32c>=2.7 in /opt/conda/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->-r requirements.txt (line 7)) (2.7.1)
# Requirement already satisfied: bounded-pool-executor in /opt/conda/lib/python3.11/site-packages (from pqdm>=0.1->earthaccess->-r requirements.txt (line 4)) (0.0.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from pqdm>=0.1->earthaccess->-r requirements.txt (line 4)) (4.66.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->hsclient==1.1.6->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->hsclient==1.1.6->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->hsclient==1.1.6->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->hsclient==1.1.6->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.11/site-packages (from s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (2.21.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (3.11.13)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.28.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 1)) (3.0.48)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.11/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: jupyterlab-server~=2.19 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.27.3)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.14.2)
# Requirement already satisfied: jupyter-ydoc~=0.2.4 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: nbclassic in /opt/conda/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: jinja2>=2.1 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests_oauthlib->hsclient==1.1.6->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: botocore<1.37.2,>=1.37.0 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (1.37.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (2.4.8)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess->-r requirements.txt (line 4)) (1.18.3)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 1)) (4.3.6)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.6.2.post1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.9.3)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: y-py<0.7.0,>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-ydoc~=0.2.4->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server~=2.19->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server~=2.19->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server~=2.19->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.11/site-packages (from nbclassic->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.11/site-packages (from nbformat->notebook->jupyter->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: isodate in /opt/conda/lib/python3.11/site-packages (from rdflib<6.0.0->hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.11/site-packages (from rdflib<6.0.0->hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.11/site-packages (from terminado>=0.8.3->notebook->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from email-validator->hsmodels>=1.0.4->hsclient==1.1.6->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab->jupyter->-r requirements.txt (line 1)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /opt/conda/lib/python3.11/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /opt/conda/lib/python3.11/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (24.8.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.9.0.20241003)
# Using cached hsclient-1.1.6-py3-none-any.whl (20 kB)
# Installing collected packages: hsclient
#   Attempting uninstall: hsclient
#     Found existing installation: hsclient 1.1.2
#     Uninstalling hsclient-1.1.2:
#       Successfully uninstalled hsclient-1.1.2
# Successfully installed hsclient-1.1.6

# %%
import os
import pandas
import xarray
import hsclient
import numpy as np
import earthaccess
import matplotlib.pyplot as plt
from datetime import datetime, timedelta


# import user credentials and set for earthaccess login
# this file contains two variables:
#    username='<username>'
#    password='<password>'
# import creds

# %% [markdown]
# List the available community discharge datasets by querying HydroShare. We already know that these data are located in the following resource: https://www.hydroshare.org/resource/38feeef698ca484b907b7b3eb84ad05b.
#
# We can programatically access these data using the globally unique identifier found at the end of this url.

# %%
guid = '38feeef698ca484b907b7b3eb84ad05b'

# %% [markdown]
# Connect to HydroShare using the hsclient Python library. Since we're not using credentials, we'll only have access to public data.

# %%
hs = hsclient.HydroShare()

# %% [markdown]
# Load this resource into memory and print metadata about it. This resource happens to contain references to other resources that contain the data we want. Display all of these associated resources so we can choose which one we want to work with.

# %%
swot_collection = hs.resource(guid)

# %%
def print_metadata(resource, indent=''):
    print(f"{indent}{'Title:': <20} {resource.metadata.title}")
    print(f"{indent}{'URL:': <20} {resource.metadata.url}")
    print(f"{indent}{'Subject Keywords:': <20} {resource.metadata.subjects}")

# %%
print('----------------')
print('Resource Summary')
print('----------------')
swot_collection = hs.resource(guid)
print_metadata(swot_collection)
print('Related Resources')

for relation in swot_collection.metadata.relations:
    # get the resource metadata for each relation
    # using a guid extracted from the relation metadata
    try:
        resource = hs.resource(relation.value.split('/')[-1])
        print()
        print_metadata(resource, indent='    ')
    except Exception:
        # we may encounter exceptions if we try to access resources
        # that we do not have permissions for.
        pass
# Out:
# ----------------
# Resource Summary
# ----------------
# Title:               Surface Water and Ocean Topography  Hydrology Community Discharge (SWOT SHCQ)
# URL:                 http://www.hydroshare.org/resource/38feeef698ca484b907b7b3eb84ad05b
# Subject Keywords:    ['Discharge', 'Depth', 'SWOT', 'Velocity', 'width']
# Related Resources
#
#     Title:               TEST_SWOT SHCQ file checker utility
#     URL:                 http://www.hydroshare.org/resource/ae99b1157a174b3a9a9ea69fa093d85e
#     Subject Keywords:    ['discharge', 'notebook', 'SWOT', 'SWOT SHCQ']
#
#     Title:               River Discharge of Rhine at 17 locations from Jan 2020 to June 2024
#     URL:                 http://www.hydroshare.org/resource/11ddd3102dee413da781de9164bee16e
#     Subject Keywords:    ['River discharge at 17 gauges']
#
#     Title:               MSU SWOT ADCP data
#     URL:                 http://www.hydroshare.org/resource/fc8ac0d1a65f409d93cf80655cb97411
#     Subject Keywords:    ['Yellowstone River', 'Calibration', 'SWOT', 'ADCP', 'Montana State University', 'Chile', 'Validation', 'Discharge Measurements']
#
#     Title:               Alaska SWOT ADCP Datasets
#     URL:                 http://www.hydroshare.org/resource/ded3514a76f048d5ad1a552e17ee93fd
#     Subject Keywords:    ['Depth', 'discharge', 'SWOT', 'Velocity', 'Width']
#
#     Title:               TEST_Example Data For Surface Water and Ocean Topography Hydrology Community Discharge (SWOT SHCQ)
#     URL:                 http://www.hydroshare.org/resource/cbf1587a7f1f4beb9693a3d1973385da
#     Subject Keywords:    ['discharge', 'velocity', 'depth', 'SWOT']
#
#     Title:               Surface Water and Ocean Topography  Hydrology Community Discharge (SWOT SHCQ)
#     URL:                 http://www.hydroshare.org/resource/96f1928c95834539ba260ab65ea8db8e
#     Subject Keywords:    ['Depth', 'SWOT', 'Velocity', 'Discharge']
#
#     Title:               Piliouras Noatak SWOT ADCP data
#     URL:                 http://www.hydroshare.org/resource/93ee8708a1444415a79cce4eefb1df4a
#     Subject Keywords:    ['river discharge', 'SWOT', 'discharge', 'streamflow', 'ADCP']
#
#     Title:               Harlan SWOT ADCP data
#     URL:                 http://www.hydroshare.org/resource/6c997113b8d84271b293e05710dec311
#     Subject Keywords:    ['streamflow', 'satellite hydrology', 'SWOT', 'discharge', 'ADCP']
#
#     Title:               TEST_Example Data II For Surface Water and Ocean Topography Hydrology Community Discharge (SWOT SHCQ)1.2
#     URL:                 http://www.hydroshare.org/resource/465672b67a6d467384eba0724ca979ea
#     Subject Keywords:    ['depth', 'velocity', 'SWOT', 'discharge']

# %% [markdown]
# Download streamflow data for one of these resources to analyze. Choose a globally unique identifer from one of the urls listed in the output above.

# %%
res = hs.resource('11ddd3102dee413da781de9164bee16e')

# %% [markdown]
# Now that this resource is loaded into memory, we can can query the files that are associated with it. Once we've identified a file that we're interested in, we can download and begin working with it.

# %%
res.files()
# Out:
# ['BFG_Rhine_SHCQ2_V3_2020-2024.csv']

# %%
res.file_download('BFG_Rhine_SHCQ2_V3_2020-2024.csv')
# Out:
# 'BFG_Rhine_SHCQ2_V3_2020-2024.csv'

# %% [markdown]
# Load this dataset using `pandas`. We'll need to do a little cleaning to fix datetime formats.

# %%
# load the csv file
df = pandas.read_csv('BFG_Rhine_SHCQ2_V3_2020-2024.csv')

# set the index to the date listed in the dataset
df['date'] = pandas.to_datetime(df["Time_('dd-mm-yyyy')"], errors='coerce')
df.set_index(df.date, inplace=True)

# drop times that couldn't be converted
df = df[~df.index.isnull()]

df
# Out:
#                Reach_ID         Node_ID  SWORD_Version         X          Y  \
# date
# 2020-01-01  23267000711  23267000710361             16  7.529275  47.711059
# 2020-02-01  23267000711  23267000710361             16  7.529275  47.711059
# 2020-03-01  23267000711  23267000710361             16  7.529275  47.711059
# 2020-04-01  23267000711  23267000710361             16  7.529275  47.711059
# 2020-05-01  23267000711  23267000710361             16  7.529275  47.711059
# ...                 ...             ...            ...       ...        ...
# 2024-08-05  23261000181  23261000180251             16  6.245594  51.829252
# 2024-09-05  23261000181  23261000180251             16  6.245594  51.829252
# 2024-10-05  23261000181  23261000180251             16  6.245594  51.829252
# 2024-11-05  23261000181  23261000180251             16  6.245594  51.829252
# 2024-12-05  23261000181  23261000180251             16  6.245594  51.829252
#
#            Time_('dd-mm-yyyy')  Q_(m^3/s_daily)  Qu_(m^3/s_daily)  WSE_(m)  \
# date
# 2020-01-01          01-01-2020        46.878947             -9999    -9999
# 2020-02-01          02-01-2020        46.795833             -9999    -9999
# 2020-03-01          03-01-2020        45.566667             -9999    -9999
# 2020-04-01          04-01-2020        44.900000             -9999    -9999
# 2020-05-01          05-01-2020        44.900000             -9999    -9999
# ...                        ...              ...               ...      ...
# 2024-08-05          08-05-2024      3090.937500             -9999    -9999
# 2024-09-05          09-05-2024      3365.833333             -9999    -9999
# 2024-10-05          10-05-2024      3312.916667             -9999    -9999
# 2024-11-05          11-05-2024      3081.458333             -9999    -9999
# 2024-12-05          12-05-2024      2933.020833             -9999    -9999
#
#             WSEu_(m)  ...  Cross-sectionalAreau_(m^2)  MaxV_(m/s)  \
# date                  ...
# 2020-01-01     -9999  ...                       -9999       -9999
# 2020-02-01     -9999  ...                       -9999       -9999
# 2020-03-01     -9999  ...                       -9999       -9999
# 2020-04-01     -9999  ...                       -9999       -9999
# 2020-05-01     -9999  ...                       -9999       -9999
# ...              ...  ...                         ...         ...
# 2024-08-05     -9999  ...                       -9999       -9999
# 2024-09-05     -9999  ...                       -9999       -9999
# 2024-10-05     -9999  ...                       -9999       -9999
# 2024-11-05     -9999  ...                       -9999       -9999
# 2024-12-05     -9999  ...                       -9999       -9999
#
#             MaxVu_(m/s)  MeanV_(m/s)  MeanVu_(m/s)  MaxD_(m)  MaxDu_(m)  \
# date
# 2020-01-01        -9999        -9999         -9999     -9999      -9999
# 2020-02-01        -9999        -9999         -9999     -9999      -9999
# 2020-03-01        -9999        -9999         -9999     -9999      -9999
# 2020-04-01        -9999        -9999         -9999     -9999      -9999
# 2020-05-01        -9999        -9999         -9999     -9999      -9999
# ...                 ...          ...           ...       ...        ...
# 2024-08-05        -9999        -9999         -9999     -9999      -9999
# 2024-09-05        -9999        -9999         -9999     -9999      -9999
# 2024-10-05        -9999        -9999         -9999     -9999      -9999
# 2024-11-05        -9999        -9999         -9999     -9999      -9999
# 2024-12-05        -9999        -9999         -9999     -9999      -9999
#
#             MeanD_(m)  MeanDu_(m)       date
# date
# 2020-01-01      -9999       -9999 2020-01-01
# 2020-02-01      -9999       -9999 2020-02-01
# 2020-03-01      -9999       -9999 2020-03-01
# 2020-04-01      -9999       -9999 2020-04-01
# 2020-05-01      -9999       -9999 2020-05-01
# ...               ...         ...        ...
# 2024-08-05      -9999       -9999 2024-08-05
# 2024-09-05      -9999       -9999 2024-09-05
# 2024-10-05      -9999       -9999 2024-10-05
# 2024-11-05      -9999       -9999 2024-11-05
# 2024-12-05      -9999       -9999 2024-12-05
#
# [10673 rows x 23 columns]

# %% [markdown]
# List the reach identifiers that exist in the data downloaded from HydroShare.

# %%
df.Reach_ID.unique()
# Out:
# array([23267000711, 23267000121, 23267000081, 23267000071, 23267000031,
#        23265000051, 23263000281, 23263000081, 23261000511, 23261000471,
#        23261000441, 23261000391, 23261000251, 23261000211, 23261000201,
#        23261000181])

# %% [markdown]
# Plot the discharge for one of these reaches.

# %%
reach_id = 23267000081
df.sort_index(inplace=True)
df.loc[df.Reach_ID == reach_id]['Q_(m^3/s_daily)'].plot(grid=True,
                                                        linestyle='',
                                                        marker='.',
                                                        ylabel='Daily Discharge [cms]',
                                                        title=f'Measured River Discharge @ {reach_id}');

# %% [markdown]
# Next we'll collect modeled streamflow from the Science on Swords (SoS) project. First we need to connect to EarthData using the username and password stored in our `creds.py` file.

# %%
os.environ["EARTHDATA_USERNAME"] = creds.username
os.environ["EARTHDATA_PASSWORD"] = creds.password

# login to earthacces
auth = earthaccess.login(strategy="environment")

# %% [markdown]
# Search and locate the data granules that are available. Print some metadata about each one.

# %%
# Search and locate granules
granule_info = earthaccess.search_data(
    short_name="SWOT_L4_DAWG_SOS_DISCHARGE",
    temporal=("2023-01-01", "2025-01-01"),
)
i = 0
for collection in granule_info:
    print(f'Collection Index: {i}')
    print(collection['umm']['CollectionReference']['ShortName'])
    print(collection['umm']['DataGranule']['ArchiveAndDistributionInformation'][-1]['Name'])
    print(collection['umm']['SpatialExtent']['HorizontalSpatialDomain']['Geometry']['BoundingRectangles'])
    print()
    i += 1
# Out:
# Collection Index: 0
# SWOT_L4_DAWG_SOS_DISCHARGE
# na_sword_v16_SOS_unconstrained_0001_20240611T010141_results.nc
# [{'WestBoundingCoordinate': -166.397, 'SouthBoundingCoordinate': 8.09, 'EastBoundingCoordinate': 8.09, 'NorthBoundingCoordinate': 82.311}]
#
# Collection Index: 1
# SWOT_L4_DAWG_SOS_DISCHARGE
# na_sword_v16_SOS_unconstrained_0001_20240726T123358_results.nc
# [{'WestBoundingCoordinate': -166.397, 'SouthBoundingCoordinate': 8.09, 'EastBoundingCoordinate': 8.09, 'NorthBoundingCoordinate': 82.311}]
#
# Collection Index: 2
# SWOT_L4_DAWG_SOS_DISCHARGE
# eu_sword_v16_SOS_unconstrained_0001_20240726T123345_results.nc
# [{'WestBoundingCoordinate': -21.794, 'SouthBoundingCoordinate': 25.382, 'EastBoundingCoordinate': 25.382, 'NorthBoundingCoordinate': 81.115}]
#
# Collection Index: 3
# SWOT_L4_DAWG_SOS_DISCHARGE
# sa_sword_v16_SOS_unconstrained_0001_20240726T123343_priors.nc
# [{'WestBoundingCoordinate': -81.139, 'SouthBoundingCoordinate': -52, 'EastBoundingCoordinate': -52, 'NorthBoundingCoordinate': 11.097}]
#
# Collection Index: 4
# SWOT_L4_DAWG_SOS_DISCHARGE
# af_sword_v16_SOS_unconstrained_0001_20240726T123343_results.nc
# [{'WestBoundingCoordinate': -16.598, 'SouthBoundingCoordinate': -34.496, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 37.025}, {'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -34.496, 'EastBoundingCoordinate': -34.496, 'NorthBoundingCoordinate': 37.025}]
#
# Collection Index: 5
# SWOT_L4_DAWG_SOS_DISCHARGE
# oc_sword_v16_SOS_unconstrained_0001_20240726T123327_priors.nc
# [{'WestBoundingCoordinate': 95.318, 'SouthBoundingCoordinate': -46.58, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 18.477}, {'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -46.58, 'EastBoundingCoordinate': -46.58, 'NorthBoundingCoordinate': 18.477}]
#
# Collection Index: 6
# SWOT_L4_DAWG_SOS_DISCHARGE
# eu_sword_v15_SOS_unconstrained_0001_20240228T205029_results.nc
# [{'WestBoundingCoordinate': -21.794, 'SouthBoundingCoordinate': 25.382, 'EastBoundingCoordinate': 25.382, 'NorthBoundingCoordinate': 81.115}]
#
# Collection Index: 7
# SWOT_L4_DAWG_SOS_DISCHARGE
# sa_sword_v15_SOS_unconstrained_0001_20240228T205034_priors.nc
# [{'WestBoundingCoordinate': -81.139, 'SouthBoundingCoordinate': -52, 'EastBoundingCoordinate': -52, 'NorthBoundingCoordinate': 11.097}]
#
# Collection Index: 8
# SWOT_L4_DAWG_SOS_DISCHARGE
# na_sword_v15_SOS_unconstrained_0001_20240228T205032_results.nc
# [{'WestBoundingCoordinate': -166.397, 'SouthBoundingCoordinate': 8.09, 'EastBoundingCoordinate': 8.09, 'NorthBoundingCoordinate': 82.311}]
#
# Collection Index: 9
# SWOT_L4_DAWG_SOS_DISCHARGE
# sa_sword_v16_SOS_unconstrained_0001_20240608T010854_results.nc
# [{'WestBoundingCoordinate': -81.139, 'SouthBoundingCoordinate': -52, 'EastBoundingCoordinate': -52, 'NorthBoundingCoordinate': 11.097}]
#
# Collection Index: 10
# SWOT_L4_DAWG_SOS_DISCHARGE
# af_sword_v16_SOS_unconstrained_0001_20240608T010910_priors.nc
# [{'WestBoundingCoordinate': -16.598, 'SouthBoundingCoordinate': -34.496, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 37.025}, {'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -34.496, 'EastBoundingCoordinate': -34.496, 'NorthBoundingCoordinate': 37.025}]
#
# Collection Index: 11
# SWOT_L4_DAWG_SOS_DISCHARGE
# eu_sword_v16_SOS_unconstrained_0001_20240608T010920_priors.nc
# [{'WestBoundingCoordinate': -21.794, 'SouthBoundingCoordinate': 25.382, 'EastBoundingCoordinate': 25.382, 'NorthBoundingCoordinate': 81.115}]

# %% [markdown]
# Open these files and print the NetCDF files that are stored for each granule. We'll use this information to determine which dataset to load into memory. To determine which file we should access we'll just look at the urls below to figure this out, this can be done more elegantly in the future.

# %%
files = earthaccess.open(granule_info)
files
# Out:
# QUEUEING TASKS | :   0%|          | 0/24 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/24 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/24 [00:00<?, ?it/s]
# [<File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/na_sword_v16_SOS_unconstrained_0001_20240611T010141_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/na_sword_v16_SOS_unconstrained_0001_20240611T010141_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/na_sword_v16_SOS_unconstrained_0001_20240726T123358_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/na_sword_v16_SOS_unconstrained_0001_20240726T123358_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v16_SOS_unconstrained_0001_20240726T123345_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v16_SOS_unconstrained_0001_20240726T123345_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/sa_sword_v16_SOS_unconstrained_0001_20240726T123343_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/sa_sword_v16_SOS_unconstrained_0001_20240726T123343_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/af_sword_v16_SOS_unconstrained_0001_20240726T123343_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/af_sword_v16_SOS_unconstrained_0001_20240726T123343_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/oc_sword_v16_SOS_unconstrained_0001_20240726T123327_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/oc_sword_v16_SOS_unconstrained_0001_20240726T123327_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v15_SOS_unconstrained_0001_20240228T205029_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v15_SOS_unconstrained_0001_20240228T205029_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/sa_sword_v15_SOS_unconstrained_0001_20240228T205034_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/sa_sword_v15_SOS_unconstrained_0001_20240228T205034_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/na_sword_v15_SOS_unconstrained_0001_20240228T205032_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/na_sword_v15_SOS_unconstrained_0001_20240228T205032_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/sa_sword_v16_SOS_unconstrained_0001_20240608T010854_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/sa_sword_v16_SOS_unconstrained_0001_20240608T010854_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/af_sword_v16_SOS_unconstrained_0001_20240608T010910_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/af_sword_v16_SOS_unconstrained_0001_20240608T010910_priors.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v16_SOS_unconstrained_0001_20240608T010920_results.nc>,
#  <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v16_SOS_unconstrained_0001_20240608T010920_priors.nc>]

# %% [markdown]
# We need to load two groups within the dataset; `reaches` and `hivdi`. The first contains information about the SWORD reaches that exist in the dataset and the latter is one of several discharge models that can be loaded.

# %%
# %%time
print(f'Loading the "Reaches" group in file: {files[4].full_name}')
ds_reaches = xarray.open_dataset(files[4],
                                 group='reaches',
                                 engine='h5netcdf',
                                 decode_cf=False,    
                                 decode_times=False, 
                                 decode_coords=False)
ds_reaches
# Out:
# Loading File: <File-like object HTTPFileSystem, https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v16_SOS_unconstrained_0001_20240726T123345_results.nc>
# CPU times: user 2.26 s, sys: 1.1 s, total: 3.36 s
# Wall time: 1min 18s
# <xarray.Dataset> Size: 9MB
# Dimensions:       (num_reaches: 30363)
# Dimensions without coordinates: num_reaches
# Data variables:
#     reach_id      (num_reaches) int64 243kB ...
#     x             (num_reaches) float64 243kB ...
#     y             (num_reaches) float64 243kB ...
#     river_name    (num_reaches) <U65 8MB ...
#     observations  (num_reaches) object 243kB ...
#     time          (num_reaches) object 243kB ...

# %%
# %%time
print(f'Loading the "hivdi" group in file: {files[4].full_name}')
ds_hivdi = xarray.open_dataset(files[4],
                           group='hivdi',
                           engine='h5netcdf',
                           decode_cf=False,    
                           decode_times=False, 
                           decode_coords=False,
                        )
ds_hivdi
# Out:
# Loading the "Reaches" group in file: https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_L4_DAWG_SOS_DISCHARGE/eu_sword_v16_SOS_unconstrained_0001_20240726T123345_results.nc
# CPU times: user 1.86 s, sys: 895 ms, total: 2.76 s
# Wall time: 57 s
# <xarray.Dataset> Size: 972kB
# Dimensions:  (num_reaches: 30363)
# Dimensions without coordinates: num_reaches
# Data variables:
#     Q        (num_reaches) object 243kB ...
#     A0       (num_reaches) float64 243kB ...
#     beta     (num_reaches) float64 243kB ...
#     alpha    (num_reaches) float64 243kB ...

# %% [markdown]
# Combine these datasets using the common num_reaches coordinate. This is necessary for us to select hidvi estimates by reach name or identifier.

# %%
ds_merged = xarray.combine_by_coords([ds_reaches, ds_hivdi])

# %% [markdown]
# Isolate the data corresponding with the reach we have observations for.

# %%
# use the mask to filter our data

mask = (ds_merged.reach_id == reach_id).compute()

ds_filtered = ds_merged.where(mask, drop=True)

d = ds_filtered.to_dataframe().reset_index().explode(['time', 'Q'])

# %% [markdown]
# Convert our 'time' column into datetime objects for pretty plotting.

# %%
reference_date = datetime(2000, 1, 1, 0, 0, 0)
d['datetime'] = d['time'].apply(lambda x: reference_date + timedelta(seconds=x))
d.set_index('datetime', inplace=True)

# %% [markdown]
# Create a plot containing the observed discharge that was collected from HydroShare and the `hivdi` strea

# %%
# Set up plot
fig = plt.figure(figsize=(10,10))
ax1 = plt.subplot(311)

# Plot SoS data
d.Q.plot(ax=ax1)

# Plot Observed data
df.sort_index(inplace=True)
df.loc[df.Reach_ID == reach_id]['Q_(m^3/s_daily)'].plot(linestyle='', marker='.', ax=ax1);

# Define labels and title
ax1.set_ylabel('Discharge [CMS]');
ax1.set_xlabel('Time');

ax1.set_xlim(d.index[0], d.index[-1])

plt.xticks(rotation = 45);

plt.suptitle(f"Discharge Timeseries from HIVDI for the {ds_reaches.where(ds_reaches.reach_id == reach_id, drop=True).river_name.item()}, identifier: {reach_id}.");

plt.grid()
